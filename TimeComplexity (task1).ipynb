# %%
import numpy as np
from random import randint
from time import time

# %%
timestamps_const = []
timestamps_sum = []
timestamps_prod = []
timestamps_Npoly = []
timestamps_Hpoly = []
timestamps_bubble = []
timestamps_quick = []
timestamps_tim = []
timestamps_matmul = []

# %%
# Function to create array with length = n
def n_array(n):
    return np.random.rand(n)

# %%
# Constant function
def const(array):
    const = 1
#    new_array = []
#    for i in array:
#        new_array.append(const)
    return np.full(len(array), const)

# %%
# The sum of elements
def sum_elem(array):
    sum_ = 0
    new_array = []
    for i in array:
        sum_ += i
    for i in range(len(array)):
        new_array.append(sum_)
    return new_array

# %%
# The product of elements
def prod_elem(array):
    prod = 1
    new_array = []
    for i in array:
        prod *= i
    for i in range(len(array)):
        new_array.append(prod)
    return new_array

# %%
v = n_array(5)

# %%
v
# Out:
# array([0.67675869, 0.95340191, 0.4401982 , 0.64717391, 0.5108306 ])

# %%
# Naive_Polynomial
def Naive_Poly(array):
    y = 0
    for i in range(len(array)):
        p = 1
        for j in range(i):
            p = p * 1.5
        y += array[i] * p
    return y

# %%
def Horner_Poly(array):
    y = array[0]
    for i in range(1, len(array)):
        y = y * 1.5 + array[i]
    return y

# %%
def Bubble_sort(array):
    n = len(array)
    for i in range(n - 1):
        for j in range(0, n - i - 1):
            if array[j] > array[j + 1]:
                array[j], array[j + 1] = array[j + 1], array[j]

# %%
def partition(array, low, high):
    
    i = (low - 1)
    temp = array[high]
    for j in range(low, high):
        if array[j] <= temp:
            i += 1
            array[i], array[j] = array[j], array[i]
    
    array[i + 1], array[high] = array[high], array[i + 1]
    return i + 1 

def Quick_sort(array, low, high):
    if len(array) == 1:
        return array
    if low < high:
        part = partition(array, low, high)
        Quick_sort(array, low, part - 1)
        Quick_sort(array, part + 1, high)

# %%
def Tim_sort(array):
    array.sort()

# %%
def matmul(A, B):
    zip_b = zip(*B)
    zip_b = list(zip_b)
    return [[sum(ele_a*ele_b for ele_a, ele_b in zip(row_a, col_b)) 
             for col_b in zip_b] for row_a in A]

# %%
A = np.random.randint(0, 10, size=(5, 5))
B = np.random.randint(0, 10, size=(5, 5))

# %%
matmul(A, B)
# Out:
# [[96, 133, 123, 107, 76],
#  [95, 136, 147, 108, 49],
#  [51, 126, 105, 60, 50],
#  [121, 104, 145, 141, 46],
#  [87, 104, 109, 97, 57]]

# %% [markdown]
# ### Запуск

# %% [markdown]
# 1

# %%
for i in range(1, 2001):
    a = time()
    arr = n_array(i)
    const(arr)
    b = time()

    c = time()
    arr = n_array(i)
    const(arr)
    d = time()

    e = time()
    arr = n_array(i)
    const(arr)
    f = time()

    g = time()
    arr = n_array(i)
    const(arr)
    h = time()
    
    timestamps_const.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %% [markdown]
# 2

# %%
for i in range(1, 2001):
    a = time()
    arr = n_array(i)
    sum_elem(arr)
    b = time()

    c = time()
    arr = n_array(i)
    sum_elem(arr)
    d = time()

    e = time()
    arr = n_array(i)
    sum_elem(arr)
    f = time()

    g = time()
    arr = n_array(i)
    sum_elem(arr)
    h = time()
    
    timestamps_sum.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %% [markdown]
# 3

# %%
for i in range(1, 2001):
    a = time()
    arr = n_array(i)
    prod_elem(arr)
    b = time()

    c = time()
    arr = n_array(i)
    prod_elem(arr)
    d = time()

    e = time()
    arr = n_array(i)
    prod_elem(arr)
    f = time()

    g = time()
    arr = n_array(i)
    prod_elem(arr)
    h = time()
    
    timestamps_prod.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %% [markdown]
# 4

# %%
for i in range(1, 2001):
    a = time()
    arr = n_array(i)
    Naive_Poly(arr)
    b = time()

    c = time()
    arr = n_array(i)
    Naive_Poly(arr)
    d = time()

    e = time()
    arr = n_array(i)
    Naive_Poly(arr)
    f = time()

    g = time()
    arr = n_array(i)
    Naive_Poly(arr)
    h = time()
    
    timestamps_Npoly.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)
# Out:
# <ipython-input-74-b6b51f3b6855>:8: RuntimeWarning: overflow encountered in double_scalars
#   y += array[i] * p

# %%
for i in range(1, 2001):
    a = time()
    arr = n_array(i)
    Horner_Poly(arr)
    b = time()

    c = time()
    arr = n_array(i)
    Horner_Poly(arr)
    d = time()

    e = time()
    arr = n_array(i)
    Horner_Poly(arr)
    f = time()

    g = time()
    arr = n_array(i)
    Horner_Poly(arr)
    h = time()
    
    timestamps_Hpoly.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)
# Out:
# <ipython-input-68-ec89dee09ae9>:4: RuntimeWarning: overflow encountered in double_scalars
#   y = y * 1.5 + array[i]

# %% [markdown]
# 5

# %%
for i in range(1, 1001):
    a = time()
    arr = n_array(i)
    Bubble_sort(arr)
    b = time()

    c = time()
    arr = n_array(i)
    Bubble_sort(arr)
    d = time()

    e = time()
    arr = n_array(i)
    Bubble_sort(arr)
    f = time()

    g = time()
    arr = n_array(i)
    Bubble_sort(arr)
    h = time()
    
    timestamps_bubble.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %% [markdown]
# 6

# %%
for i in range(1, 2001):
    a = time()
    arr = n_array(i)
    n = len(arr) - 1
    Quick_sort(arr, 0, n)
    b = time()

    c = time()
    arr = n_array(i)
    n = len(arr) - 1
    Quick_sort(arr, 0, n)
    d = time()

    e = time()
    arr = n_array(i)
    n = len(arr) - 1
    Quick_sort(arr, 0, n)
    f = time()

    g = time()
    arr = n_array(i)
    n = len(arr) - 1
    Quick_sort(arr, 0, n)
    h = time()
    
    timestamps_quick.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %% [markdown]
# 7

# %%
for i in range(1, 2001):
    a = time()
    Tim_sort(arr)
    b = time()

    c = time()
    arr = n_array(i)
    Tim_sort(arr)
    d = time()

    e = time()
    arr = n_array(i)
    Tim_sort(arr)
    f = time()

    g = time()
    arr = n_array(i)
    Tim_sort(arr)
    h = time()
    
    timestamps_tim.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %% [markdown]
# 8

# %%
for i in range(1, 150):
    a = time()
    A = np.random.randint(0, 10, size=(i, i))
    B = np.random.randint(0, 10, size=(i, i))
    matmul(A, B)
    b = time()

    c = time()
    A = np.random.randint(0, 10, size=(i, i))
    B = np.random.randint(0, 10, size=(i, i))
    matmul(A, B)
    d = time()

    e = time()
    A = np.random.randint(0, 10, size=(i, i))
    B = np.random.randint(0, 10, size=(i, i))
    matmul(A, B)
    f = time()

    g = time()
    A = np.random.randint(0, 10, size=(i, i))
    B = np.random.randint(0, 10, size=(i, i))
    matmul(A, B)
    h = time()
    
    timestamps_matmul.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %%
len(timestamps_tim)
# Out:
# 2000

# %%
timestamps_matmul
# Out:
# [0.00948721170425415,
#  0.0,
#  0.00025016069412231445,
#  0.0002510547637939453,
#  0.0004991888999938965,
#  0.0004996657371520996,
#  0.000499427318572998,
#  0.0009993910789489746,
#  0.0010010004043579102,
#  0.0012500882148742676,
#  0.0017492175102233887,
#  0.0019965767860412598,
#  0.002253115177154541,
#  0.0027504563331604004,
#  0.002999424934387207,
#  0.0035002827644348145,
#  0.0037503838539123535,
#  0.0039934515953063965,
#  0.004500329494476318,
#  0.004499673843383789,
#  0.005006134510040283,
#  0.0062500834465026855,
#  0.005499064922332764,
#  0.006500422954559326,
#  0.007000088691711426,
#  0.00950080156326294,
#  0.009493112564086914,
#  0.01729762554168701,
#  0.0112496018409729,
#  0.011995255947113037,
#  0.013498663902282715,
#  0.015007436275482178,
#  0.01574850082397461,
#  0.017494678497314453,
#  0.018255293369293213,
#  0.02025127410888672,
#  0.02399921417236328,
#  0.02874445915222168,
#  0.02475529909133911,
#  0.02799975872039795,
#  0.05124533176422119,
#  0.05100661516189575,
#  0.046249210834503174,
#  0.062249183654785156,
#  0.05550050735473633,
#  0.05200010538101196,
#  0.04799896478652954,
#  0.048250675201416016,
#  0.048749685287475586,
#  0.051494479179382324,
#  0.0830073356628418,
#  0.06449782848358154,
#  0.09200060367584229,
#  0.06599968671798706,
#  0.06749981641769409,
#  0.08449417352676392,
#  0.10000729560852051,
#  0.08274435997009277,
#  0.10802620649337769,
#  0.133750319480896,
#  0.15071582794189453,
#  0.14524608850479126,
#  0.14049696922302246,
#  0.1310068964958191,
#  0.12774443626403809,
#  0.16775667667388916,
#  0.139248788356781,
#  0.1702500581741333,
#  0.22356057167053223,
#  0.19099992513656616,
#  0.19649553298950195,
#  0.1987484097480774,
#  0.18224966526031494,
#  0.2055034041404724,
#  0.20750051736831665,
#  0.2409961223602295,
#  0.19225579500198364,
#  0.2257435917854309,
#  0.2445065975189209,
#  0.24750369787216187,
#  0.29133903980255127,
#  0.2892500162124634,
#  0.31574416160583496,
#  0.3037506937980652,
#  0.34974879026412964,
#  0.3659746050834656,
#  0.36026567220687866,
#  0.3562275767326355,
#  0.3560004234313965,
#  0.35925590991973877,
#  0.3804997205734253,
#  0.4254952669143677,
#  0.46574866771698,
#  0.4557560682296753,
#  0.46050000190734863,
#  0.4585007429122925,
#  0.4980013370513916,
#  0.5484933257102966,
#  0.5896957516670227,
#  0.4852111339569092,
#  0.5770184993743896,
#  0.57472825050354,
#  0.5680422186851501,
#  0.5737589001655579,
#  0.6355051398277283,
#  0.7309974431991577,
#  0.6244961023330688,
#  0.6577497124671936,
#  0.7232496738433838,
#  0.7855015993118286,
#  0.6717540621757507,
#  0.8202448487281799,
#  0.728506326675415,
#  0.8182504177093506,
#  0.7482495903968811,
#  0.8492506146430969,
#  0.7987425327301025,
#  0.8835004568099976,
#  0.8880063891410828,
#  0.8562443852424622,
#  0.8972488045692444,
#  0.9845010638237,
#  0.9725000858306885,
#  1.0792489051818848,
#  1.091037392616272,
#  0.9962509870529175,
#  1.0675050616264343,
#  1.1202446222305298,
#  1.2995041012763977,
#  1.1717500686645508,
#  1.0982491374015808,
#  1.1739951968193054,
#  1.1942551136016846,
#  1.4955004453659058,
#  1.2384998798370361,
#  1.3324992060661316,
#  1.2335005402565002,
#  1.4537463188171387,
#  1.4147531390190125,
#  1.4157439470291138,
#  1.4755005836486816,
#  1.6215065717697144,
#  1.4197516441345215,
#  1.647748589515686,
#  1.640492558479309,
#  1.5947561264038086,
#  1.6092449426651,
#  1.5990052819252014,
#  1.734249770641327]

# %%
for i in range(150, 200):
    a = time()
    A = np.random.randint(0, 10, size=(i, i))
    B = np.random.randint(0, 10, size=(i, i))
    matmul(A, B)
    b = time()

    c = time()
    A = np.random.randint(0, 10, size=(i, i))
    B = np.random.randint(0, 10, size=(i, i))
    matmul(A, B)
    d = time()

    e = time()
    A = np.random.randint(0, 10, size=(i, i))
    B = np.random.randint(0, 10, size=(i, i))
    matmul(A, B)
    f = time()

    g = time()
    A = np.random.randint(0, 10, size=(i, i))
    B = np.random.randint(0, 10, size=(i, i))
    matmul(A, B)
    h = time()
    
    timestamps_matmul.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %% [markdown]
# ### Графики

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for contant")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.plot(timestamps_const)
plt.legend('Experimental')
plt.plot(np.linspace(0.00025,0.00025, num=2000))
plt.legend('Theoretical')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for Naive polynomial")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.plot(timestamps_Npoly)
plt.legend('Experimental')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for Horner polynomial")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.plot(timestamps_Hpoly)
plt.legend('Experimental')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for contant")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.title("Time measurement for sum")
plt.plot(timestamps_sum)
plt.legend('Experimental')
plt.plot(np.linspace(0,timestamps_sum[-1], num=2000))
plt.legend('Theoretical')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for contant")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.title("Time measurement for prod")
plt.plot(timestamps_prod)
plt.legend('Experimental')
plt.plot(np.linspace(0,timestamps_prod[-1], num=2000))
plt.legend('Theoretical')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for contant")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.title("Time measurement for BubbleSort")
plt.plot(timestamps_bubble)
plt.legend('Experimental')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for contant")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.title("Time measurement for QuickSort")
plt.plot(timestamps_quick)
plt.legend('Experimental')
plt.grid(True)

# %% [markdown]
# TimSort

# %%
time_tim = []

# %%
MINIMUM= 32
  
def find_minrun(n): 
  
    r = 0
    while n >= MINIMUM: 
        r |= n & 1
        n >>= 1
    return n + r 
  
def insertion_sort(array, left, right): 
    for i in range(left+1,right+1):
        element = array[i]
        j = i-1
        whileb element<array[j] and j>=left :
            array[j+1] = array[j]
            j -= 1
        array[j+1] = element
    return array
              
def merge(array, l, m, r): 
  
    array_length1= m - l + 1
    array_length2 = r - m 
    left = []
    right = []
    for i in range(0, array_length1): 
        left.append(array[l + i]) 
    for i in range(0, array_length2): 
        right.append(array[m + 1 + i]) 
  
    i=0
    j=0
    k=l
   
    while j < array_length2 and  i < array_length1: 
        if left[i] <= right[j]: 
            array[k] = left[i] 
            i += 1
  
        else: 
            array[k] = right[j] 
            j += 1
  
        k += 1
  
    while i < array_length1: 
        array[k] = left[i] 
        k += 1
        i += 1
  
    while j < array_length2: 
        array[k] = right[j] 
        k += 1
        j += 1
  
def tim_sort(array): 
    n = len(array) 
    minrun = find_minrun(n) 
  
    for start in range(0, n, minrun): 
        end = min(start + minrun - 1, n - 1) 
        insertion_sort(array, start, end) 
   
    size = minrun 
    while size < n: 
  
        for left in range(0, n, 2 * size): 
  
            mid = min(n - 1, left + size - 1) 
            right = min((left + 2 * size - 1), (n - 1)) 
            merge(array, left, mid, right) 
  
        size = 2 * size

# %%
for i in range(1, 2001):
    a = time()
    tim_sort(arr)
    b = time()

    c = time()
    arr = n_array(i)
    tim_sort(arr)
    d = time()

    e = time()
    arr = n_array(i)
    tim_sort(arr)
    f = time()

    g = time()
    arr = n_array(i)
    tim_sort(arr)
    h = time()
    
    time_tim.append(((b-a) + (d-c) + (f-e) + (h-g)) / 4)

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for contant")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.title("Time measurement for TimSort")
plt.plot(time_tim)
plt.legend('Experimental')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
plt.title("Time measurement for contant")
plt.xlabel('array length', fontsize=16)
plt.ylabel('time(s)', fontsize=14)
plt.title("Time measurement for Matrix multiplication")
plt.plot(timestamps_matmul)
plt.legend('Experimental')
plt.grid(True)
